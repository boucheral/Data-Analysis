# %% [markdown]
# # Analysis 2
# * **Which people sent and recieved the most emails**

# %%
import re
import string
from collections import Counter
import glob
import os
from email.parser import Parser
import json

# %% [markdown]
# *This uses the EnronData.py to import all of the emails here*

# %%
emailPattern = re.compile('.+@enron.com')

## Check address and name to see if they're in the format we need
def skip(a,n):
    
    if emailPattern.search(n) :
        return True
    
    if a.startswith('enron'):
        return True
    
    if '<' in a :
        return True
    
    bad = ['enron', '_', 'employees', 'team', 'temp', 'administrator', 'management']
    
    for x in bad :
        if x in n.lower() :
            return True
        
    return False
   
## If the name is Last, First swap to First Last else return the string without doing anything
def swap(s) :
    if (',' in s) :
        x = s.split(',')
        return x[1].strip() + ' ' + x[0].strip()
    else :
        return s
    
# Takes emails and the names raw string, cleans it, and returns a dictionary with k = email v = corresponding name
def emailsAndNames(address, names) :
    
    regexp1 = re.compile('<[^>]+>|.+@.+')
    re2 = re.compile('<[^>]+>[,]?')
    
    if (address is None or names is None) :
        return None
    
    a = [x.strip() for x in address.split(',')]

    if (re2.search(names)) :
        n = re2.sub('|', names )
        n = [swap(x.strip()) for x in n.split('|')]
    else :
        n = [x.strip() for x in names.split(',')]
   
    d = {}
    x = 0
    while x < len(a) and x < len(n) :
        if skip(a[x], n[x]) :
            x = x + 1
            continue
        if emailPattern.match(a[x]) :
            d[a[x]] = n[x]
        x = x + 1
        
    if d :
        return d
    else :
        return None

# %%
## takes an email and returns a dictionary with keys = [to,from,cc] and values = [list of emails]
def getAddresses(email) :
    to = email['to']
    tox = email['X-To']
    f = email['from']
    fx = email['X-From']
    cc = email['cc']
    ccx = email['X-Cc']
    
    addresses = {'from' : emailsAndNames(f, fx), 'to' : emailsAndNames(to, tox), 'cc' : emailsAndNames(cc, ccx)} 
    
    if (not addresses['from'] and not addresses['to'] and not addresses['cc']):
        return None
    else :
        return addresses

# %%
#Takes the file and converts to email format
def parseEmailFile(fileName) :
    with open(fileName, "r") as f:
        data = f.read()

    email = Parser().parsestr(data)
    return email

# Get all emails in file directory
def getEmails(fileString) :
    l = []
    
    searchDirectory(fileString, l)
    
    return l

# recursive method that adds email addresses to list if it's a file or calls itself again if it's a directory
def searchDirectory(fileString,l) :
    names = glob.glob(fileString + '/*')
    for name in names :
        if (os.path.isdir(name)) :
            searchDirectory(name, l)
        elif (os.path.isfile(name)) :
            email = parseEmailFile(name)
            a = getAddresses(email)
            if a :
                l.append(getAddresses(email))

# %%
loc = '../../Data/maildir\\'
names = glob.glob('../../Data/maildir/*')


for name in names :
    
    fname = name.replace(loc, '')
    emails = getEmails(name)
    newloc = '../../Data/Addresses/' + fname + '.json'
    f = open(newloc, 'w+')
    f.write(json.dumps(emails, indent=4, sort_keys=True))
    f.close()

# %%
people = {}

lists = {'from' : [], 'to' : [], 'cc' : []}

names = glob.glob('../../Data/Addresses/*')
for name in names :
    
    with open(name, 'r') as file:    
        data = json.load(file)
        
    if not data :
        continue
        
    for x in data :
        if x['to'] is None or x['from'] is None :
            continue

        for y in ['from', 'to', 'cc'] :
            if x[y] is None :
                continue
        
            for k,v in x[y].items() :
                people[k] = v
        
            lists[y].extend(x[y].keys())
        
people
# Out:
# {'phillip.allen@enron.com': 'Phillip Allen',
#  'keith.holst@enron.com': 'Keith Holst',
#  'david.delainey@enron.com': "Stephens 'vickersore@aol.com'",
#  'paula.harris@enron.com': 'Paula Harris',
#  'ina.rangel@enron.com': 'Ina Rangel',
#  'jeffrey.hodge@enron.com': 'Jeffrey T Hodge',
#  'cindy.cicchetti@enron.com': 'Cindy Cicchetti',
#  'christopher.calger@enron.com': 'Christopher F Calger',
#  'kathy.moore@enron.com': 'Kathy M Moore',
#  'john.lavorato@enron.com': 'John Lavorato',
#  'kenneth.shulklapper@enron.com': 'Kenneth Shulklapper',
#  'paul.lucci@enron.com': 'Paul T Lucci',
#  'frank.hayden@enron.com': 'Frank Hayden',
#  'frank.ermis@enron.com': 'Frank Ermis',
#  'jay.reitmeyer@enron.com': 'Jay Reitmeyer',
#  'mike.grigsby@enron.com': 'Mike Grigsby',
#  'thomas.martin@enron.com': 'Thomas Martin',
#  'cooper.richey@enron.com': 'Cooper Richey',
#  'cindy.long@enron.com': 'Dan Masters@ect',
#  'matthew.lenhart@enron.com': 'Matthew Lenhart',
#  'suzanne.nicholie@enron.com': 'Suzanne Nicholie',
#  'colleen.sullivan@enron.com': 'Erin Stus',
#  'brad.mcsherry@enron.com': 'Brad McSherry',
#  'hunter.shively@enron.com': 'Hunter Shively',
#  'bruce.ferrell@enron.com': 'Bruce Ferrell',
#  'rebecca.cantrell@enron.com': 'Rebecca Cantrell',
#  'stephanie.sever@enron.com': 'Stephanie Sever',
#  'stephen.harrington@enron.com': 'Stephen Harrington',
#  'sunil.dalal@enron.com': 'Sunil Dalal',
#  'mary@enron.com': 'Mary',
#  'paul.kaufman@enron.com': 'Paul Kaufman',
#  'barry.steinhart@enron.com': 'Barry Steinhart',
#  'jane.tholt@enron.com': 'Jane M Tholt',
#  'steven.south@enron.com': 'Steven P South',
#  'chris.gaskill@enron.com': 'Chris Gaskill',
#  'beth.perlman@enron.com': 'Beth Perlman',
#  'john.arnold@enron.com': 'John Arnold',
#  'scott.neal@enron.com': 'Scott Neal',
#  'fletcher.sturm@enron.com': 'Fletcher Sturm',
#  'al.pollard@enron.com': 'Al Pollard',
#  'frank.davis@enron.com': 'Frank L Davis',
#  'niamh.clarke@enron.com': 'Michael Bradley',
#  'sonya.clarke@enron.com': 'Sonya Clarke',
#  'randall.gay@enron.com': 'Randall L Gay',
#  'celeste.roberts@enron.com': 'Celeste Roberts',
#  'christi.nicolay@enron.com': 'Vinh Nguyen',
#  'james.steffes@enron.com': 'James Steffes',
#  'jeff.dasovich@enron.com': 'Jeff Dasovich',
#  'joe.hartsoe@enron.com': 'Susan Mara',
#  'mary.hain@enron.com': 'Mary Hain',
#  'richard.sanders@enron.com': 'Richard Sanders',
#  'richard.shapiro@enron.com': 'Richard Shapiro',
#  'stephanie.miller@enron.com': 'Stephanie Miller',
#  'steven.kean@enron.com': 'Steven Kean',
#  'susan.mara@enron.com': 'Susan Mara',
#  'gary.taylor@enron.com': 'Mark Tawney',
#  'felix.buitron@enron.com': 'Felix Buitron',
#  'tim.belden@enron.com': 'Tim Belden',
#  'torrey.moorer@enron.com': 'Torrey Moorer',
#  'jeff.richter@enron.com': 'Jeff Richter',
#  'robert.badeer@enron.com': 'Robert Badeer',
#  'jeffrey.gossett@enron.com': 'Jeffrey C Gossett',
#  'tara.sweitzer@enron.com': 'Tara Sweitzer',
#  'tori.kuykendall@enron.com': 'Tori Kuykendall',
#  'dawn.kenne@enron.com': 'Dawn C Kenne',
#  'laird.dyer@enron.com': 'Laird Dyer',
#  'hector.campos@enron.com': 'Hector Campos',
#  'sarah.novosel@enron.com': 'Sarah Novosel',
#  'david.wile@enron.com': 'David Wile',
#  'suzanne.marshall@enron.com': 'Gary Maestas',
#  'scott.tholan@enron.com': 'Scott Tholan',
#  'mark.miles@enron.com': 'Mark Miles',
#  'stephane.brodeur@enron.com': 'Stephane Brodeur',
#  'brian.hoskins@enron.com': 'Brian Hoskins',
#  'tracy.arthur@enron.com': 'Tracy L Arthur',
#  'aamir.maniar@enron.com': 'Aamir Maniar',
#  'brian.terp@enron.com': 'Brian Terp',
#  'chris.figueroa@enron.com': 'Chris Figueroa',
#  'david.loosley@enron.com': 'David Loosley',
#  'jeff.gray@enron.com': 'Datren Williams',
#  'jennifer.bagwell@enron.com': 'Jennifer Bagwell',
#  'john.gordon@enron.com': 'John Gordon',
#  'john.kiani@enron.com': 'John Kiani',
#  'joseph.wagner@enron.com': 'Joseph Wagner',
#  'maria.arefieva@enron.com': 'Maria Arefieva',
#  'massimo.marolo@enron.com': 'Massimo Marolo',
#  'matt.smith@enron.com': 'Matt Smith',
#  'matthew.frank@enron.com': 'Matthew Frank',
#  'mauricio.mora@enron.com': 'Mauricio Mora',
#  'reagan.rorschach@enron.com': 'Reagan Rorschach',
#  'robert.wheeler@enron.com': 'Christopher Watts',
#  'scott.baukney@enron.com': 'Scott Baukney',
#  'sean.kiehne@enron.com': 'Kyle Berryman',
#  'steve.jacobellis@enron.com': 'Steve Jacobellis',
#  'victor.gonzalez@enron.com': 'Chad South',
#  'vincent.wagner@enron.com': 'Vincent Wagner',
#  'vladi.pimenov@enron.com': 'Vladi Pimenov',
#  'zachary.sampson@enron.com': 'Zachary Sampson',
#  'ben.jacoby@enron.com': 'Rika Imai',
#  'carl.tricoli@enron.com': 'Carl Tricoli',
#  'catherine.simoes@enron.com': 'Bob Shults',
#  'edward.baughman@enron.com': 'Edward D Baughman',
#  'elsa.piekielniak@enron.com': 'Elsa Piekielniak',
#  'fred.lagrasta@enron.com': 'Fred Lagrasta',
#  'gary.hickerson@enron.com': 'Gary Hickerson',
#  'geoff.storey@enron.com': 'Geoff Storey',
#  'james.lewis@enron.com': 'James C Lewis',
#  'kevin.mcgowan@enron.com': 'Kevin Mcgowan',
#  'mark.knippa@enron.com': 'Mark Knippa',
#  'max.yzaguirre@enron.com': 'Max Yzaguirre',
#  'michael.beyer@enron.com': 'Michael J Beyer',
#  'richard.dimichele@enron.com': 'Daniel Diamond',
#  'stephen.horn@enron.com': 'Stephen R Horn',
#  'tony.mataya@enron.com': 'Rachel Massey',
#  'monique.sanchez@enron.com': 'Monique Sanchez',
#  'brent.price@enron.com': 'Timothy M Norton',
#  'steve.jackson@enron.com': 'Steve Jackson',
#  'william.kelly@enron.com': 'William Kelly',
#  'donna.fulton@enron.com': 'Donna Fulton',
#  'stephen.wolfe@enron.com': 'Stephen Wolfe',
#  'jim.brysch@enron.com': 'Jim Brysch',
#  'imelda.frayre@enron.com': 'Imelda Frayre',
#  'tim.heizenrader@enron.com': 'Tim Heizenrader',
#  'kimberly.olinger@enron.com': 'Kimberly S Olinger',
#  'robert.superty@enron.com': 'Robert Superty',
#  'julie.gomez@enron.com': 'Julie A Gomez',
#  'candace.womack@enron.com': 'Candace Womack',
#  'brenda.flores-cuellar@enron.com': 'Brenda Flores-Cuellar',
#  'slewis2@enron.com': 'Susan Lewis',
#  'dean.sacerdote@enron.com': 'Dean Sacerdote',
#  'dale.neuner@enron.com': 'Dale Neuner',
#  'naomi.johnston@enron.com': 'Naomi Johnston',
#  'perfmgmt@enron.com': '"Performance Evaluation Process (PEP)"',
#  'pallen@enron.com': 'PHILLIP K" "ALLEN',
#  'kim.ward@enron.com': 'Kim Ward',
#  'alyse.herasimchuk@enron.com': 'Alyse Herasimchuk',
#  'andrew.fastow@enron.com': 'Andrew Fastow',
#  'eric.shaw@enron.com': 'Eric Shaw',
#  'joseph.deffner@enron.com': 'Joseph Deffner',
#  'ken.rice@enron.com': 'Ken Rice',
#  'kevin.garland@enron.com': 'Scott Gahn',
#  'richard.causey@enron.com': 'Richard Causey',
#  'robina.barker-bennett@enron.com': 'Robina Barker-Bennett',
#  'stuart.staley@enron.com': 'Stuart Staley',
#  'billy.lemmons@enron.com': 'Billy Lemmons Jr.',
#  'donna.jones@enron.com': 'Donna Jones',
#  'john.walt@enron.com': 'John Walt',
#  'traci.warner@enron.com': 'Traci Warner',
#  'lisa.jacobson@enron.com': 'Lisa Jacobson',
#  'alan.comnes@enron.com': 'Alan Comnes',
#  'lisa.jones@enron.com': 'Lisa Jones',
#  'ray.alvarez@enron.com': 'Ray Alvarez',
#  'ned.higgins@enron.com': 'Ned Higgins',
#  'eric.benson@enron.com': 'Eric Benson',
#  'susan.scott@enron.com': 'Susan M Scott',
#  'mary.gray@enron.com': 'Mary Griff Gray',
#  'andrea.richards@enron.com': 'Andrea Richards',
#  'karen.buckley@enron.com': 'Karen Buckley',
#  'julie.pechersky@enron.com': 'Larry Pavlou',
#  'chad.landry@enron.com': 'Simone La rose',
#  'leslie.lawner@enron.com': 'Leslie Lawner',
#  'ruth.concannon@enron.com': 'Ruth Concannon',
#  'mark.taylor@enron.com': 'Mark Taylor',
#  'sara.solorio@enron.com': 'Sara Solorio',
#  'barry.tycholiz@enron.com': 'Barry Tycholiz',
#  'jess.hewitt@enron.com': 'Olga Herrera',
#  'tiffany.miller@enron.com': 'Tiffany Miller',
#  'philip.polsky@enron.com': 'Philip Polsky',
#  'mark.whitt@enron.com': 'Mark Whitt',
#  'nicole.cortez@enron.com': 'Nicole Cortez',
#  'theresa.staab@enron.com': 'Theresa Staab',
#  'todd.burke@enron.com': 'Todd Burke',
#  'kim.bolton@enron.com': 'Kim Bolton',
#  'angela.collins@enron.com': 'Angela Collins',
#  'don.black@enron.com': 'Don Black',
#  'amanda.huble@enron.com': 'Amanda Huble',
#  'tara.piazze@enron.com': 'Tara Piazze',
#  'body.shop@enron.com': 'Body Shop',
#  'jeanie.slone@enron.com': 'Jeanie Slone',
#  'russ.whitton@enron.com': 'Russ Whitton',
#  'bridgette.anderson@enron.com': 'Bridgette Anderson',
#  'sally.beck@enron.com': 'Sally Beck',
#  'c@enron.com': 'C',
#  'patti.sullivan@enron.com': 'Patti Sullivan',
#  'nick.politis@enron.com': 'Larry Valderrama',
#  'kristin.walsh@enron.com': 'Kristin Walsh',
#  'vladimir.gorny@enron.com': 'Vladimir Gorny',
#  'jason.moore@enron.com': 'Jason Moore',
#  'jonathan.mckay@enron.com': 'Jonathan Mckay',
#  'mary.gosnell@enron.com': 'Mary G Gosnell',
#  'faith.killen@enron.com': 'Faith Killen',
#  'colin.tonks@enron.com': 'Drew Tingleaf',
#  'bob.schorr@enron.com': 'Bob Schorr',
#  'stephen.stock@enron.com': 'Stephen Stock',
#  'shelley.corman@enron.com': 'Shelley Corman',
#  'anne.bike@enron.com': 'Anne Bike',
#  'greg.piper@enron.com': 'Greg Piper',
#  'john.shafer@enron.com': 'John Shafer',
#  'joyce.teixeira@enron.com': 'Joyce Teixeira',
#  'andy.zipper@enron.com': 'Andy Zipper',
#  'leah.arsdall@enron.com': 'Leah Van Arsdall',
#  'mark.scott@enron.com': 'Mark Scott',
#  'donna.greif@enron.com': 'Donna Greif',
#  'timothy.hamilton@enron.com': 'Timothy J Hamilton',
#  'andy.rodriquez@enron.com': 'Andy Rodriquez',
#  'charles.yeung@enron.com': 'Shane Yelverton',
#  'd..steffes@enron.com': 'James D. Steffes',
#  'dave.perrino@enron.com': 'Dave Perrino',
#  'debra.davidson@enron.com': 'Debra Davidson',
#  'j..kean@enron.com': 'Richard Shapiro',
#  'janel.guerrero@enron.com': 'Kristin Walsh',
#  'jennifer.thome@enron.com': 'Jennifer Thome',
#  'k..allen@enron.com': 'Phillip K. Allen',
#  'l..nicolay@enron.com': 'Christi L. Nicolay',
#  'linda.robertson@enron.com': 'Linda Robertson',
#  'm..landwehr@enron.com': 'Susan M. Landwehr',
#  'michael.roan@enron.com': 'Michael Roan',
#  'robert.frank@enron.com': 'Don Black',
#  'steve.walton@enron.com': 'Steve Walton',
#  'sue.nord@enron.com': 'Sue Nord',
#  'susan.lindberg@enron.com': 'Susan Lindberg',
#  'w..cantrell@enron.com': 'Rebecca W. Cantrell',
#  'ed.mcmichael@enron.com': 'Ed McMichael Jr.',
#  'l..gay@enron.com': 'Randall L. Gay',
#  'm..tholt@enron.com': 'Jane M. Tholt',
#  'mark.courtney@enron.com': 'Mark Courtney',
#  'p..hewitt@enron.com': 'Jess P. Hewitt',
#  'suzanne.calcagno@enron.com': 'Suzanne Calcagno',
#  'guillermo.canovas@enron.com': 'Guillermo Canovas',
#  'melinda.pharms@enron.com': 'Thach C. Phan',
#  'bodyshop@enron.com': 'Bodyshop',
#  'savita.puthigai@enron.com': 'Savita Puthigai',
#  'traders.eol@enron.com': 'EOL North America Traders',
#  'angela.connelly@enron.com': 'Angela Connelly',
#  'brad.richter@enron.com': 'Brad Richter',
#  'carl.carter@enron.com': 'Carl Carter',
#  'center.eol@enron.com': 'EOL Call Center',
#  'houston.product@enron.com': 'Product Control - Houston',
#  'kevin.meredith@enron.com': 'Kevin Meredith',
#  'leonardo.pacheco@enron.com': 'Leonardo Pacheco',
#  'lindsay.renaud@enron.com': 'Lindsay Renaud',
#  'mark.pickering@enron.com': 'Mark Pickering',
#  'teresa.mandola@enron.com': 'Teresa Mandola',
#  'ken.shulklapper@enron.com': 'Nikhil Shah',
#  'martin.cuilla@enron.com': 'Martin Cuilla',
#  'veronica.espinoza@enron.com': 'Veronica Espinoza',
#  'a..allen@enron.com': 'Thresa A. Allen',
#  'a..martin@enron.com': 'Thomas A. Martin',
#  'a..price@enron.com': 'Brent A. Price',
#  'a..shankman@enron.com': 'Jeffrey A. Shankman',
#  'alex.hernandez@enron.com': 'Fredrik Eriksson',
#  'andrea.ring@enron.com': 'Andrea Ring',
#  'angelo.miroballi@enron.com': 'Houston Milstead',
#  'ann.murphy@enron.com': 'Melissa Ann Murphy',
#  'audrey.cook@enron.com': 'Audrey Cook',
#  'b..boxx@enron.com': 'Pam B. Boxx',
#  'b..fleming@enron.com': 'Matthew B. Fleming',
#  'bernard.dahanayake@enron.com': 'Bernard Dahanayake',
#  'bob.bowen@enron.com': 'Bob Bowen',
#  'brad.coleman@enron.com': 'Fred Cohagan',
#  'bryan.hull@enron.com': 'Bryan Hull',
#  'bryce.baxter@enron.com': 'Bryce Baxter',
#  'c..aucoin@enron.com': 'Berney C. Aucoin',
#  'carol.st.@enron.com': 'Carol St. Clair',
#  'chris.germany@enron.com': 'Chris Germany',
#  'chris.lambie@enron.com': 'Chris Lambie',
#  'christian.yoder@enron.com': 'Christian Yoder',
#  'christina.bangle@enron.com': 'Christina Bangle',
#  'clinton.anderson@enron.com': 'Clinton Anderson',
#  'craig.breslau@enron.com': 'Craig Breslau',
#  'craig.taylor@enron.com': 'Craig Taylor',
#  'cyndie.balfour-flanagan@enron.com': 'Cyndie Balfour-Flanagan',
#  'cynthia.franklin@enron.com': 'Cynthia Franklin',
#  'd..baughman@enron.com': 'Misty Barrett',
#  'd..sorenson@enron.com': 'Jefferson D. Sorenson',
#  'dan.mccairns@enron.com': 'Dan McCairns',
#  'daniel.quezada@enron.com': 'Daniel Quezada',
#  'daniel.reck@enron.com': 'Daniel Reck',
#  'darren.espey@enron.com': 'Darren Espey',
#  'david.parquet@enron.com': 'David Parquet',
#  'dayem.khandker@enron.com': 'Ryan Hinze',
#  'debra.perlingiere@enron.com': 'Rick Perkins',
#  'dennis.benevides@enron.com': 'Dennis Benevides',
#  'denver.plachy@enron.com': 'Denver Plachy',
#  'derek.bailey@enron.com': 'Derek Bailey',
#  'diane.anderson@enron.com': 'Diane Anderson',
#  'dutch.quigley@enron.com': 'Dutch Quigley',
#  'e..dickson@enron.com': 'Stacy E. Dickson',
#  'ellen.wallumrod@enron.com': 'Ellen Wallumrod',
#  'eric.bass@enron.com': 'Eric Bass',
#  'eric.boyt@enron.com': 'Eric Boyt',
#  'eric.moon@enron.com': 'Eric Moon',
#  'f..brawner@enron.com': 'Sandra F. Brawner',
#  'f..keavey@enron.com': 'Peter F. Keavey',
#  'genia.fitzgerald@enron.com': 'Genia Fitzgerald',
#  'george.huan@enron.com': 'George Huan',
#  'gerald.nemec@enron.com': 'Gary Nelson',
#  'greg.brazaitis@enron.com': 'Greg Brazaitis',
#  'gregg.penman@enron.com': 'Gregg Penman',
#  'gregory.schockling@enron.com': 'Gregory Schockling',
#  'h..foster@enron.com': 'Chris H. Foster',
#  'h..lewis@enron.com': 'Andrew H. Lewis',
#  'h..otto@enron.com': 'Charles H. Otto',
#  'j..ewing@enron.com': 'Linda J. Ewing',
#  'j..farmer@enron.com': 'Daren J. Farmer',
#  'j..hanson@enron.com': 'Kristen J. Hanson',
#  'j..miller@enron.com': 'Mike J. Miller',
#  'j..sturm@enron.com': 'Fletcher J. Sturm',
#  'jabari.martin@enron.com': 'Jabari Martin',
#  'jake.thomas@enron.com': 'Jake Thomas',
#  'janelle.scheuer@enron.com': 'Janelle Scheuer',
#  'jay.knoblauh@enron.com': 'Jay Knoblauh',
#  'jeff.stephens@enron.com': 'Jeff Stephens',
#  'jennifer.blay@enron.com': 'Jennifer Blay',
#  'jennifer.fraser@enron.com': 'Jennifer Fraser',
#  'jennifer.jennings@enron.com': 'Jennifer Jennings',
#  'jim.willis@enron.com': 'Jim Willis',
#  'joanne.harris@enron.com': 'JoAnne Harris',
#  'joe.hunter@enron.com': 'Larry Joe Hunter',
#  'john.grass@enron.com': 'David Gorte',
#  'john.griffith@enron.com': 'John Griffith',
#  'john.singer@enron.com': 'John M Singer',
#  'jonathan.horne@enron.com': 'Jonathan Horne',
#  'joni.fisher@enron.com': 'Joni Fisher',
#  'judy.thorne@enron.com': 'Patti Thompson',
#  'judy.townsend@enron.com': 'Judy Townsend',
#  'jungsuk.suh@enron.com': 'Jungsuk Suh',
#  'k..ratnala@enron.com': 'Murthy Rao',
#  'kathryn.bussell@enron.com': 'Kathryn Bussell',
#  'kelli.little@enron.com': 'Kelli Little',
#  'kevin.bosse@enron.com': 'Kevin Bosse',
#  'kevin.ruscitti@enron.com': 'Kevin Ruscitti',
#  'l..dinari@enron.com': 'Sabra L. Dinari',
#  'l..kelly@enron.com': 'Shelly Keller',
#  'l..mims@enron.com': 'Patrice L. Mims',
#  'larry.may@enron.com': 'Larry May',
#  'lee.jackson@enron.com': 'Lee Jackson',
#  'leslie.reeves@enron.com': 'Leslie Reeves',
#  'lester.rawson@enron.com': 'Lester Rawson',
#  'lisa.gillette@enron.com': 'Lisa Gillette',
#  'lisa.lees@enron.com': 'Lisa Lees',
#  'lisa.mellencamp@enron.com': 'Lisa Mellencamp',
#  'lisa.valderrama@enron.com': 'Lisa Valderrama',
#  'loftus.fitzwater@enron.com': 'Loftus Fitzwater',
#  'louis.dicarlo@enron.com': 'Louis Dicarlo',
#  'lucy.ortiz@enron.com': 'Lucy Ortiz',
#  'm.hall@enron.com': 'Bob M Hall',
#  'maria.garza@enron.com': 'Maria Garza',
#  'mark.breese@enron.com': 'Mark Breese',
#  "martin.o'leary@enron.com": "Martin O'Leary",
#  'mary.cook@enron.com': 'Mary Cook',
#  'mary.ogden@enron.com': 'Mary Ogden',
#  'maureen.smith@enron.com': 'Maureen Smith',
#  'michael.etringer@enron.com': 'Michael Etringer',
#  'mike.maggi@enron.com': 'Mike Maggi',
#  'n..gilbert@enron.com': 'George N. Gilbert',
#  'n..gray@enron.com': 'Sheila Graves',
#  'nathan.hlavaty@enron.com': 'Nathan Hlavaty',
#  'nelson.ferries@enron.com': 'Nelson Ferries',
#  'p..south@enron.com': 'Steven P. South',
#  'patrick.hanse@enron.com': 'Patrick Hanse',
#  'paul.tate@enron.com': 'Paul Tate',
#  'r..barker@enron.com': 'James R. Barker',
#  'r..brackett@enron.com': 'Debbie R. Brackett',
#  'r..conner@enron.com': 'Andrew R. Conner',
#  'r..lilly@enron.com': 'Kyle R. Lilly',
#  'ragan.bond@enron.com': 'Ragan Bond',
#  'raiford.smith@enron.com': 'Raiford Smith',
#  'randy.otto@enron.com': 'Randy Otto',
#  'rebecca.phillips@enron.com': 'Rebecca Phillips',
#  'richard.deming@enron.com': 'Richard Deming',
#  'ron.green@enron.com': 'Ron Green',
#  'russell.diamond@enron.com': 'Russell Diamond',
#  's..bradford@enron.com': 'William S. Bradford',
#  's..bryan@enron.com': 'Linda S. Bryan',
#  's..olinger@enron.com': 'Kimberly S. Olinger',
#  's..pollan@enron.com': 'Adam Plager',
#  's..shively@enron.com': 'Hunter S. Shively',
#  's..theriot@enron.com': 'Kim S. Theriot',
#  'santiago.garcia@enron.com': 'Santiago Garcia',
#  'sara.shackleton@enron.com': 'Sara Shackleton',
#  'sarah.mulholland@enron.com': 'Sarah Mulholland',
#  'scott.goodell@enron.com': 'Scott Goodell',
#  'scott.hendrickson@enron.com': 'Scott Hendrickson',
#  'sean.riordan@enron.com': 'Sean Riordan',
#  'shauywn.smith@enron.com': 'Shauywn Smith',
#  'sheetal.patel@enron.com': 'Sheetal Patel',
#  'sheila.glover@enron.com': 'Mark Frevert',
#  'sherry.pendegraft@enron.com': 'Sherry Pendegraft',
#  'shonnie.daniel@enron.com': 'Shonnie Daniel',
#  'souad.mahmassani@enron.com': 'Souad Mahmassani',
#  'stacey.richardson@enron.com': 'Stacey Richardson',
#  'stephanie.stehling@enron.com': 'Stephanie Stehling',
#  'steve.neal@enron.com': 'Steve Neal',
#  'steve.van@enron.com': 'Steve Van Hooser',
#  'steven.curlee@enron.com': 'Steven Curlee',
#  't..hodge@enron.com': 'Jeffrey T. Hodge',
#  't..lucci@enron.com': 'Paul T. Lucci',
#  't..muzzy@enron.com': 'Charles T. Muzzy',
#  'tana.jones@enron.com': 'Tana Jones',
#  'tanya.rohauer@enron.com': 'Tanya Rohauer',
#  'teresa.seibel@enron.com': 'Teresa Seibel',
#  'thomas.mcfatridge@enron.com': 'Thomas McFatridge',
#  'tiffany.smith@enron.com': 'Tiffany Smith',
#  'tom.donohoe@enron.com': 'Tom Donohoe',
#  'tom.moran@enron.com': 'Tom Moran',
#  'tracy.ngo@enron.com': 'Kourtney Nelson',
#  'w..eubanks@enron.com': 'David W. Eubanks Jr.',
#  'w..pereira@enron.com': 'Susan W. Pereira',
#  'william.stuart@enron.com': 'William Stuart III',
#  'y..resendez@enron.com': 'Isabel Y. Resendez',
#  'yuan.tian@enron.com': 'Yuan Tian',
#  'kathie.grabstald@enron.com': 'Vladimir Gorny',
#  'a..gomez@enron.com': 'Jeffrey Golden',
#  'alan.aronowitz@enron.com': 'Alan Aronowitz',
#  "arnell'.'doug@enron.com": "'Doug Arnell'",
#  'brian.redmond@enron.com': 'Brian Redmond',
#  'cathy.phillips@enron.com': 'Cathy Phillips',
#  'chris.mahoney@enron.com': 'Chris Mahoney',
#  'cindy.skinner@enron.com': 'Cindy Skinner',
#  "crook'.'jody@enron.com": "'Jody Crook'",
#  'david.duran@enron.com': 'Anthony Duenner',
#  'david.leboe@enron.com': 'David Leboe',
#  'david.oxley@enron.com': 'David Oxley',
#  'deb.korkmas@enron.com': 'Deb Korkmas',
#  'ellen.fowler@enron.com': 'Ellen Fowler',
#  'eric.gonzales@enron.com': 'Eric Gonzales',
#  'f..calger@enron.com': 'Christopher F. Calger',
#  'georganne.hodges@enron.com': 'Georganne Hodges',
#  'george.mcclellan@enron.com': 'George Mcclellan',
#  'heather.purcell@enron.com': 'Heather Purcell',
#  'j.kaminski@enron.com': 'Vince J Kaminski',
#  'jean.mrha@enron.com': 'Don (Asset Mktg) Miller',
#  'jeff.andrews@enron.com': 'Jeff Andrews',
#  'john.thompson@enron.com': 'John Thompson',
#  "josey'.'scott@enron.com": "'Scott Josey'",
#  'karin.williams@enron.com': 'Karin Williams',
#  'kay.young@enron.com': 'Sherron Watkins',
#  'l..nowlan@enron.com': 'John L. Nowlan Jr.',
#  'larry.gagliardi@enron.com': 'Larry Gagliardi',
#  'larry.lawyer@enron.com': 'Larry Lawyer',
#  'laurie.mayer@enron.com': 'Laurie Mayer',
#  'louise.kitchen@enron.com': 'Louise Kitchen',
#  'm..presto@enron.com': 'Kevin M. Presto',
#  'mark.tawney@enron.com': 'Mark Tawney',
#  'mike.mcconnell@enron.com': 'Mike McConnell',
#  'neil.davies@enron.com': 'Neil Davies',
#  'randal.maffett@enron.com': 'Randal Maffett',
#  'rob.milnthorp@enron.com': 'Rob Milnthorp',
#  's..friedman@enron.com': 'Douglas S. Friedman',
#  'shanna.funkhouser@enron.com': 'Shanna Funkhouser',
#  'stanley.cocke@enron.com': 'Stanley Cocke Jr.',
#  'thomas.myers@enron.com': 'Thomas Myers',
#  "tricoli'.'carl@enron.com": "'Carl Tricoli'",
#  "ward'.'charles@enron.com": "'Charles Ward'",
#  'wes.colwell@enron.com': 'Wes Colwell',
#  'a..ryan@enron.com': 'Beth A. Ryan',
#  'april.weatherford@enron.com': 'April Weatherford',
#  "armstrong'.'kristy@enron.com": "'Kristy Armstrong'",
#  'bill.berkeland@enron.com': 'Bill Berkeland',
#  "brown'.'kimberly@enron.com": "'Kimberly Brown'",
#  'candace.parker@enron.com': 'Candace Parker',
#  'chantelle.villanueva@enron.com': 'Michelle Thomason',
#  'christina.valdez@enron.com': 'Christina Valdez',
#  "cowan'.'beth@enron.com": "'Beth Cowan'",
#  'cynthia.gonzalez@enron.com': 'Cynthia Gonzalez',
#  'donna.baker@enron.com': 'Donna Baker',
#  'e.taylor@enron.com': 'Michael E Taylor',
#  'erika.breen@enron.com': 'Erika Breen',
#  'ethan.schultz@enron.com': 'Ethan Schultz',
#  'gary.justice@enron.com': 'Gary Justice',
#  'gloria.solis@enron.com': 'Gloria Solis',
#  'gwyn.koepke@enron.com': 'Gwyn Koepke',
#  "harder'.'laura@enron.com": "'Laura Harder'",
#  'j..coneway@enron.com': 'Betty J. Coneway',
#  'j..johnston@enron.com': 'Sonia Guerra',
#  'jennifer.burns@enron.com': 'Jennifer Burns',
#  'jennifer.walker@enron.com': 'Jennifer Walker',
#  'judy.zoch@enron.com': 'Owen Zidar',
#  'katrin.haux@enron.com': 'Katrin Haux',
#  'l..miller@enron.com': 'Don Miller',
#  'lorna.ervin@enron.com': 'Lorna Ervin',
#  'margaret.dennison@enron.com': 'Stacey Dempsey',
#  'marie.taylor@enron.com': 'Helen Marie Taylor',
#  'martin.sonesson@enron.com': 'Martin Sonesson',
#  'megan.angelos@enron.com': 'Megan Angelos',
#  'michael.salinas@enron.com': 'Michael Salinas',
#  'mollie.gustafson@enron.com': 'Mollie Gustafson',
#  'nella.cappelletto@enron.com': 'Nella Cappelletto',
#  'nita.garcia@enron.com': 'Nita Garcia',
#  'pilar.cerezo@enron.com': 'Pilar Cerezo',
#  'r..shepperd@enron.com': 'Tammy R. Shepperd',
#  'r..westbrook@enron.com': 'Cherylene R. Westbrook',
#  "ralston'.'tracy@enron.com": "'Tracy Ralston'",
#  "raymond'.'maureen@enron.com": "'Maureen Raymond'",
#  'renee.ingram@enron.com': 'Renee Ingram',
#  'rhonna.palmer@enron.com': 'Rhonna Palmer',
#  'sarah.domonoske@enron.com': 'Sarah Domonoske',
#  'sharon.purswell@enron.com': 'Sharon Purswell',
#  'shelia.benke@enron.com': 'Shelia Benke',
#  'shirley.crenshaw@enron.com': 'Shirley Crenshaw',
#  'shirley.isbell@enron.com': 'Shirley Isbell',
#  'shirley.tijerina@enron.com': 'Shirley Tijerina',
#  'sue.ford@enron.com': 'Sue Ford',
#  'sunita.katyal@enron.com': 'Sunita Katyal',
#  'tammie.schoppe@enron.com': 'Tammie Schoppe',
#  'tina.rode@enron.com': 'Tina Rode',
#  'yvette.simpson@enron.com': 'Yvette Simpson',
#  'jason.wolfe@enron.com': 'Jason Wolfe',
#  'm..scott@enron.com': 'Susan M. Scott',
#  'mog.heu@enron.com': 'Mog Heu',
#  'p..adams@enron.com': 'Jacqueline P. Adams',
#  'shannon.groenewold@enron.com': 'Shannon Groenewold',
#  'shelly.mendel@enron.com': 'Shelly Mendel',
#  'suzanne.christiansen@enron.com': 'Suzanne Christiansen',
#  'zachary.mccarroll@enron.com': 'Zachary McCarroll',
#  'daniel.lisk@enron.com': 'Daniel Lisk',
#  'jason.huang@enron.com': 'Jason Huang',
#  'c..gossett@enron.com': 'Jeffrey C. Gossett',
#  'corry.bentley@enron.com': 'Corry Bentley',
#  'dana.davis@enron.com': 'Mark Dana Davis',
#  'jim.meyn@enron.com': 'Jim Meyn',
#  'jim.schwieger@enron.com': 'Jim Schwieger',
#  'lloyd.will@enron.com': 'Lloyd Will',
#  'rogers.herndon@enron.com': 'Rogers Herndon',
#  'kathryn.sheppard@enron.com': 'Kathryn Sheppard',
#  'david.ryan@enron.com': 'David Ryan',
#  'john.zufferli@enron.com': 'John Zufferli',
#  'james.bruce@enron.com': 'Albert Meyers',
#  'andy.chen@enron.com': 'Andy Chen',
#  'angela.cadena@enron.com': 'Angela Cadena',
#  'bill.williams@enron.com': 'Bill Williams III',
#  'cara.semperger@enron.com': 'Cara Semperger',
#  'chris.lackey@enron.com': 'Chris Lackey',
#  'chris.mumm@enron.com': 'Chris Mumm',
#  'darin.presto@enron.com': 'Darin Presto',
#  'dave.fuller@enron.com': 'Dave Fuller',
#  'david.frost@enron.com': 'David Frost',
#  'david.guillaume@enron.com': 'David Guillaume',
#  'diana.scholtes@enron.com': 'Diana Scholtes',
#  'don.hammond@enron.com': 'Don Hammond',
#  'ed.clark@enron.com': 'Ed Clark',
#  'edward.sacks@enron.com': 'Edward Sacks',
#  'elliot.mainzer@enron.com': 'Elliot Mainzer',
#  'fran.chang@enron.com': 'Fran Chang',
#  'fredrik.eriksson@enron.com': 'Fredrik Eriksson',
#  'g..slaughter@enron.com': 'Jeff G. Slaughter',
#  'glenn.surowiec@enron.com': 'Glenn Surowiec',
#  'gordon.savage@enron.com': 'Gordon Savage',
#  'heather.dunton@enron.com': 'Heather Dunton',
#  'holden.salisbury@enron.com': 'Holden Salisbury',
#  'jeff.shields@enron.com': 'Jeff Shields',
#  'jeffrey.oh@enron.com': 'Ravi Mujumdar',
#  'jesse.bryson@enron.com': 'Jesse Bryson',
#  'jim.buerkle@enron.com': 'Jim Buerkle',
#  'jim.gilbert@enron.com': 'Jim Gilbert',
#  'john.malowney@enron.com': 'John Malowney',
#  'john.van@enron.com': 'John Van Gelder',
#  'jonalan.page@enron.com': 'Jonalan Page',
#  'julie.sarnowski@enron.com': 'Julie Sarnowski',
#  'kate.symes@enron.com': 'Kate Symes',
#  'kortney.brown@enron.com': 'Kortney Brown',
#  'kourtney.nelson@enron.com': 'Kourtney Nelson',
#  'kysa.alport@enron.com': 'Kysa Alport',
#  'larry.soderquist@enron.com': 'Ryan Slinger',
#  'laura.wente@enron.com': 'Laura Wente',
#  'm..driscoll@enron.com': 'Michael M. Driscoll',
#  'mark.fillinger@enron.com': 'Jay Ferry',
#  'mark.guzman@enron.com': 'Mark Guzman',
#  'mark.mullen@enron.com': 'Matt Motley',
#  'matt.motley@enron.com': 'Matt Motley',
#  'michael.mcdonald@enron.com': 'Michael Mcdonald',
#  'mike.swerzbin@enron.com': 'Mike Swerzbin',
#  'minal.dalia@enron.com': 'Minal Dalia',
#  'paul.choi@enron.com': 'Paul Choi',
#  'paul.radous@enron.com': 'Paul Radous',
#  'phil.polsky@enron.com': 'Phil Polsky',
#  'samantha.law@enron.com': 'Samantha Law',
#  'sarabeth.smith@enron.com': 'Sarabeth Smith',
#  'stan.gray@enron.com': 'Stan Gray',
#  'stephen.thome@enron.com': 'Stephen Thome',
#  'steve.swain@enron.com': 'Steve Swain',
#  'stewart.rosman@enron.com': 'Stewart Rosman',
#  'susan.rance@enron.com': 'Susan Rance',
#  'todd.perry@enron.com': 'Todd Perry',
#  'tom.alonso@enron.com': 'Tom Alonso',
#  'virginia.thompson@enron.com': 'Virginia Thompson',
#  'w..donovan@enron.com': 'Terry W. Donovan',
#  'wayne.mays@enron.com': 'Wayne Mays',
#  'wendy.conwell@enron.com': 'Wendy Conwell',
#  'randy.bhatia@enron.com': 'Randy Bhatia',
#  "ryan.o'rourke@enron.com": "Ryan O'Rourke",
#  'david.marks@enron.com': 'Rodney Malcolm',
#  'doug.gilbert-smith@enron.com': 'Doug Gilbert-smith',
#  'drew.tingleaf@enron.com': 'Ravi Thuraisingham',
#  'frank.vickers@enron.com': 'Frank Vickers',
#  'harry.arora@enron.com': 'Harry Arora',
#  'heather.kroll@enron.com': 'Heather Kroll',
#  'laura.luce@enron.com': 'Laura Luce',
#  'mike.carson@enron.com': 'Mike Carson',
#  'rahil.jafry@enron.com': 'Rahil Jafry',
#  'robert.benson@enron.com': 'Robert Benson',
#  'kirk.mcdaniel@enron.com': 'Laurie Mayer',
#  "tim.o'rourke@enron.com": "Murray P. O'Neil",
#  'yevgeny.frolov@enron.com': 'Yevgeny Frolov',
#  'adrianne.engler@enron.com': 'Adrianne Engler',
#  'chad.clark@enron.com': 'Chad Clark',
#  'chris.dorland@enron.com': 'Chris Dorland',
#  'chris.mallory@enron.com': 'Chris Mallory',
#  'mike.cowan@enron.com': 'Mike Cowan',
#  'no.address@enron.com': 'Don (Asset Mktg) Miller',
#  'renee.ratcliff@enron.com': 'Renee Ratcliff',
#  'michelle.akers@enron.com': 'Michelle Akers',
#  'brad.mckay@enron.com': 'Brad Mckay',
#  'john.suarez@enron.com': 'John Suarez',
#  'm..forney@enron.com': 'John M. Forney',
#  'felicia.solis@enron.com': 'Felicia Solis',
#  'a.hernandez@enron.com': 'Jesus A Hernandez',
#  'jason.panos@enron.com': 'Jason Panos',
#  'm..singer@enron.com': 'John M. Singer',
#  "ron'.'green@enron.com": "Ron' 'Green",
#  "scott'.'hendrickson@enron.com": "Scott' 'Hendrickson",
#  'justin.rostant@enron.com': 'Justin Rostant',
#  'bob.hillier@enron.com': 'Bob Hillier',
#  'griff.gray@enron.com': 'Mary Griff Gray',
#  'jay.webb@enron.com': 'Jay Webb',
#  'thomas.engel@enron.com': 'Thomas Engel',
#  'david.draper@enron.com': 'Casey Donnell',
#  "monique'.'sanchez@enron.com": "Monique' 'Sanchez",
#  'tay.canacoo@enron.com': 'Tay Canacoo',
#  'benjamin.schoene@enron.com': 'Benjamin Schoene',
#  'corey.wilkes@enron.com': 'Corey Wilkes',
#  'j..brewer@enron.com': 'Stacey J. Brewer',
#  "john.o'conner@enron.com": "John O'Conner",
#  'justin.fernandez@enron.com': 'Justin Fernandez',
#  'walter.spiegelhauer@enron.com': 'Walter Spiegelhauer',
#  'carole.frank@enron.com': 'Carole Frank',
#  'ashley.worthing@enron.com': 'Ashley Worthing',
#  'biliana.pehlivanova@enron.com': 'Biliana Pehlivanova',
#  'kam.keiser@enron.com': 'Kam Keiser',
#  'monte.jones@enron.com': 'Monte Jones',
#  'alex.villarreal@enron.com': 'Alex Villarreal',
#  'jessica.presas@enron.com': 'Jessica Presas',
#  'kimberly.bates@enron.com': 'Kimberly Bates',
#  'laura.vuittonet@enron.com': 'Laura Vuittonet',
#  'rick.bellows@enron.com': 'Rick Bellows',
#  'pam.butler@enron.com': 'Pam Butler',
#  'greg.whalley@enron.com': 'Greg Whalley',
#  'mary.joyce@enron.com': 'Mary Joyce',
#  'jennifer.denny@enron.com': 'Jennifer Denny',
#  'c..giron@enron.com': 'Darron C. Giron',
#  'jd.buss@enron.com': 'Jd Buss',
#  'mark.smith@enron.com': 'Mark Smith',
#  'victor.munoz@enron.com': 'Victor Munoz',
#  'w..white@enron.com': 'Stacey W. White',
#  'joannie.williamson@enron.com': 'Joannie Williamson',
#  'a..hughes@enron.com': 'James A. Hughes',
#  'a..lindholm@enron.com': 'Tod A. Lindholm',
#  'adam.umanoff@enron.com': 'Adam Umanoff',
#  'bay.frank@enron.com': 'Frank Bay',
#  'ben.glisan@enron.com': 'Ben Glisan',
#  'bill.cordes@enron.com': 'Bill Cordes',
#  'bob.butts@enron.com': 'Bob Butts',
#  'charlene.jackson@enron.com': 'Charlene Jackson',
#  'cindy.olson@enron.com': 'Cindy Olson',
#  'connie.estrems@enron.com': 'Connie Estrems',
#  'dan.leff@enron.com': 'Dan Leff',
#  'danny.mccarty@enron.com': 'Danny McCarty',
#  'david.cox@enron.com': 'David Cox',
#  'e..haedicke@enron.com': 'Mark E. Haedicke',
#  'earle.joseph@enron.com': 'Joseph Earle',
#  'elizabeth.tilney@enron.com': 'Elizabeth Tilney',
#  'fernley.dyson@enron.com': 'Fernley Dyson',
#  'frank.stabler@enron.com': 'Frank Stabler',
#  'gahn.scott@enron.com': 'Scott Gahn',
#  'george.wasaff@enron.com': 'George Wasaff',
#  'j..detmering@enron.com': 'Timothy J. Detmering',
#  'james.derrick@enron.com': 'James Derrick',
#  'janet.dietrich@enron.com': 'Janet Dietrich',
#  'jeff.donahue@enron.com': 'John Disturnal',
#  'jeff.messina@enron.com': 'Jeff Messina',
#  'jeffrey.mcmahon@enron.com': 'Jeffrey McMahon',
#  'jeffrey.sherrick@enron.com': 'Karen S Owens@ees',
#  'jeremy.blachman@enron.com': 'Jeremy Blachman',
#  'jim.fallon@enron.com': 'Jim Fallon',
#  'jim.prentice@enron.com': 'Jim Prentice',
#  'joe.gold@enron.com': 'Joe Gold',
#  'joe.kishkill@enron.com': 'Joe Kishkill',
#  'john.gillis@enron.com': 'John Gillis',
#  'john.sherriff@enron.com': 'John Sherriff',
#  'julia.murray@enron.com': 'Julia Murray',
#  'keith.dodson@enron.com': 'Nora Dobin',
#  'kenneth.lay@enron.com': 'Kenneth Lay',
#  'kristina.mordaunt@enron.com': 'Jerry Thomas Moore',
#  'london.brown@enron.com': 'Michael - COO London Brown',
#  'mark.frevert@enron.com': 'Mark Frevert',
#  'mark.koenig@enron.com': 'Mark Koenig',
#  'mark.metts@enron.com': 'Mark Metts',
#  'matthew.scrimshaw@enron.com': 'Matthew Scrimshaw',
#  'michael.farmer@enron.com': 'Michael Farmer',
#  'michael.hutchinson@enron.com': 'Michael Hutchinson',
#  'mitch.taylor@enron.com': 'Mitch Taylor',
#  'paula.rieker@enron.com': 'Paula Rieker',
#  'phil.lowry@enron.com': 'Phil Lowry',
#  'raymond.bowen@enron.com': 'Raymond Bowen Jr.',
#  'rebecca.mcdonald@enron.com': 'Rebecca McDonald',
#  'rex.shelby@enron.com': 'Rex Shelby',
#  'rich.dimichele@enron.com': 'Rich Dimichele',
#  'richard.lewis@enron.com': 'Richard Lewis',
#  'rick.buy@enron.com': 'Rick Buy',
#  'rob.walls@enron.com': 'Sarah Wesner-Soong',
#  'robert.hayes@enron.com': 'Robert Hayes',
#  'robert.hermann@enron.com': 'Robert Hermann',
#  'rod.hayslett@enron.com': 'Rod Hayslett',
#  's..muller@enron.com': 'Mark S. Muller',
#  'stanley.horton@enron.com': 'Stanley Horton',
#  'vicki.sharp@enron.com': 'Vicki Sharp',
#  'wade.cline@enron.com': 'Wade Cline',
#  'amelia.alder@enron.com': 'Amelia Alder',
#  'ann.brown@enron.com': 'Carol Ann Brown',
#  'barbara.hooks@enron.com': 'Barbara Hooks',
#  'beena.pradhan@enron.com': 'Beena Pradhan',
#  'binky.davidson@enron.com': 'Marisa Rapacioli',
#  'bobbie.moody@enron.com': 'Bobbie Moody',
#  'bridget.maronge@enron.com': 'Bridget Maronge',
#  'carolyn.george@enron.com': 'Carolyn George',
#  'cheryl.kuehl@enron.com': 'Cheryl Kuehl',
#  'cindy.stark@enron.com': 'Cindy Stark',
#  'connie.blackwood@enron.com': 'Connie Blackwood',
#  'crissy.collett@enron.com': 'Crissy Collett',
#  'debbie.foot@enron.com': 'Debbie Foot',
#  'debra.hicks@enron.com': 'Debra Hicks',
#  'dolores.fisher@enron.com': 'Dolores Fisher',
#  'donna.teal@enron.com': 'Donna Teal',
#  'dortha.gray@enron.com': 'Dortha Gray',
#  'edineth.santos@enron.com': 'Edineth Santos',
#  'erica.braden@enron.com': 'Erica Braden',
#  'esmeralda.hinojosa@enron.com': 'Esmeralda Hinojosa',
#  'ginger.dernehl@enron.com': 'Ginger Dernehl',
#  'gloria.alvarez@enron.com': 'Gloria Alvarez',
#  'hilda.bourgeois-galloway@enron.com': 'Hilda Bourgeois-Galloway',
#  'inez.dauterive@enron.com': 'Inez Dauterive',
#  'j.harris@enron.com': 'Nicki Daw',
#  'janette.elbertson@enron.com': 'Janette Elbertson',
#  'janice.hogan@enron.com': 'Janice Hogan',
#  'jennifer.adams@enron.com': 'Jennifer Adams',
#  'joyce.dorsey@enron.com': 'Joyce Dorsey',
#  'julie.armstrong@enron.com': 'Julie Armstrong',
#  'k..heathman@enron.com': 'Karen K. Heathman',
#  'kathy.campos@enron.com': 'Marsha Schiller',
#  'kathy.dodgen@enron.com': 'Kathy Dodgen',
#  'kay.chapman@enron.com': 'David Delainey',
#  'kerry.ferrari@enron.com': 'Kerry Ferrari',
#  'kimberly.hillis@enron.com': 'Kimberly Hillis',
#  'l..cromwell@enron.com': 'Sheri L. Cromwell',
#  'laura.valencia@enron.com': 'Laura Valencia',
#  'lila.holst@enron.com': 'James Hollman',
#  'lillian.carroll@enron.com': 'Lillian Carroll',
#  'linda.hawkins@enron.com': 'Kimberly Hillis',
#  'liz.taylor@enron.com': 'Liz Taylor',
#  'loretta.brelsford@enron.com': 'Loretta Brelsford',
#  'lorraine.telles@enron.com': 'Lorraine Telles',
#  'lucy.marshall@enron.com': 'Peggy McCurley',
#  'marisa.rapacioli@enron.com': 'Marisa Rapacioli',
#  'marsha.schiller@enron.com': 'Jeffrey McMahon',
#  'martha.benner@enron.com': 'Martha Benner',
#  'maureen.mcvicker@enron.com': 'Melissa McPherson',
#  'nicki.daw@enron.com': 'Tammie Davis',
#  'nicole.scott@enron.com': 'Nicole Scott',
#  'nikki.slade@enron.com': 'Nikki Slade',
#  'rosalee.fleming@enron.com': 'Rosalee Fleming',
#  'rosario.boling@enron.com': 'Rosario Boling',
#  'sandy.lewelling@enron.com': 'Sandy Lewelling',
#  'sharon.dick@enron.com': 'Liz M Taylor@ECT',
#  'sharron.westbrook@enron.com': 'Sharron Westbrook',
#  'susan.fallon@enron.com': 'Fran Fagan',
#  'tammy.kovalcik@enron.com': 'Tammy Kovalcik',
#  'tina.spiller@enron.com': 'Tina Spiller',
#  'tracie.mccormack@enron.com': 'Tracie McCormack',
#  'wells.tori@enron.com': 'Tori Wells',
#  'yorleni.mendez@enron.com': 'Yorleni Mendez',
#  'a..roberts@enron.com': 'Patricia Rivera',
#  'david.forster@enron.com': 'David Forster',
#  'georgeanne.hodges@enron.com': 'Georgeanne Hodges',
#  'jenny.rub@enron.com': 'Jenny Rub',
#  'mike.curry@enron.com': 'Mike Curry',
#  'mitch.robinson@enron.com': 'Mitch Robinson',
#  'peggy.hedstrom@enron.com': 'Peggy Hedstrom',
#  'rita.wynne@enron.com': 'Rita Wynne',
#  'david.port@enron.com': 'David Port',
#  'michelle.cash@enron.com': 'Michelle Cash',
#  'johnny.ross@enron.com': 'Johnny Ross',
#  'ed.dannhaus@enron.com': 'Ed Dannhaus',
#  's..lim@enron.com': 'Francis S. Lim',
#  'casey.evans@enron.com': 'Casey Evans',
#  'erik.simpson@enron.com': 'Catherine Simoes',
#  'b..sanders@enron.com': 'Diana Sanchez',
#  'brent.dornier@enron.com': 'Brent Dornier',
#  'andrew.fairley@enron.com': 'Andrew Fairley',
#  'chrissy.grove@enron.com': 'Chrissy Grove',
#  'dmccarty@enron.com': '',
#  'timothy.heizenrader@enron.com': 'Timothy Heizenrader',
#  'jeff.golden@enron.com': 'Jeff Golden',
#  'colleen.koenig@enron.com': 'Colleen Koenig',
#  'jennifer.medcalf@enron.com': 'Jennifer Medcalf',
#  'jeff.leath@enron.com': 'Jeff Leath',
#  'tracy.ramsey@enron.com': 'Tracy Ramsey',
#  'carrie.blaskowski@enron.com': 'Carrie Blaskowski',
#  'jennifer.stewart@enron.com': 'Jason R Williams',
#  'jeffrey.shankman@enron.com': 'Jeffrey A Shankman',
#  "brian.o'rourke@enron.com": "Brian O'Rourke",
#  'jeff.youngflesh@enron.com': 'Jeff Youngflesh',
#  'kim.godfrey@enron.com': 'Kim Godfrey',
#  'edie.leschber@enron.com': 'Edie Leschber',
#  'caroline.abramo@enron.com': 'Caroline Abramo',
#  'jennifer.shipos@enron.com': 'Jennifer Shipos',
#  'kenneth.thibodeaux@enron.com': 'Kenneth Thibodeaux',
#  'sarah-joy.hunter@enron.com': 'Sarah-joy Hunter',
#  'john.will@enron.com': 'John Will',
#  'matt.harris@enron.com': 'Bruce Harris',
#  'dorothy.woster@enron.com': 'Marissa Womble',
#  'james.wininger@enron.com': 'James Wininger',
#  'karina.prizont@enron.com': 'Karina Prizont',
#  'calvin.eakins@enron.com': 'Calvin Eakins',
#  'derryl.cleaveland@enron.com': 'Mary Clark',
#  'drew.ries@enron.com': 'Drew Ries',
#  'john.gillespie@enron.com': 'John Gillespie',
#  'kelly.higgason@enron.com': 'Kelly Higgason',
#  'robert.johansen@enron.com': 'Robert Johansen',
#  'trang.dinh@enron.com': 'Trang Dinh',
#  'kayla.heitmeyer@enron.com': 'Kayla Heitmeyer',
#  'dale.clark@enron.com': 'Dale Clark',
#  'patrick.tucker@enron.com': 'Patrick Tucker',
#  'peter.goebel@enron.com': 'Peter Goebel',
#  'mike.rabon@enron.com': 'Mike Rabon',
#  'gary.waxman@enron.com': 'Gary Waxman',
#  'alan.engberg@enron.com': 'Alan Engberg',
#  'john.nowlan@enron.com': 'John L Nowlan',
#  'mark.jeffries@enron.com': 'Mark Jeffries',
#  'chaz.vaughan@enron.com': 'Chaz Vaughan',
#  'stephen.morse@enron.com': 'Stephen Morse',
#  'bob.mcauliffe@enron.com': 'Bob McAuliffe',
#  'bruce.smith@enron.com': 'Bruce Smith',
#  'darin.carlisle@enron.com': 'Darin Carlisle',
#  'douglas.cummins@enron.com': 'Douglas Cummins',
#  'jim.ogg@enron.com': 'Jim Ogg',
#  'randy.matson@enron.com': 'Randy Matson',
#  'trey.comiskey@enron.com': 'Trey Comiskey',
#  'linda.zhou@enron.com': 'Linda Zhou',
#  'brad.nebergall@enron.com': 'Arun Natraj',
#  'mike.rogala@enron.com': 'Mike Rogala',
#  'greg.reynolds@enron.com': 'Greg Reynolds',
#  'larry.ciscon@enron.com': 'Larry Ciscon',
#  'steve.pearlman@enron.com': 'Steve Pearlman',
#  'bob.shults@enron.com': 'Bob Shults',
#  'david.gallagher@enron.com': 'David Gallagher',
#  'gregor.baumerich@enron.com': 'Gregor Baumerich',
#  'paul.mead@enron.com': 'Paul Mead',
#  'tom.wilbeck@enron.com': 'Tom Wilbeck',
#  'danielle.marcinkowski@enron.com': 'Danielle Marcinkowski',
#  'kenny.soignet@enron.com': 'Kenny J Soignet',
#  'berney.aucoin@enron.com': 'Berney C Aucoin',
#  'calvin.johnson@enron.com': 'Sandra Brawner',
#  'chris.connelly@enron.com': 'Chris Connelly',
#  'chris.foster@enron.com': 'Chris H Foster',
#  'clayton.vernon@enron.com': 'Clayton Vernon',
#  'daniel.diamond@enron.com': 'Daniel Diamond',
#  'heather.kendall@enron.com': 'Heather Kendall',
#  'joseph.hrgovcic@enron.com': 'Joseph Hrgovcic',
#  'lee.papayoti@enron.com': 'Lee L Papayoti',
#  'marc.horowitz@enron.com': 'Marc Horowitz',
#  'michael.cowan@enron.com': 'Michael Cowan',
#  'paul.bieniawski@enron.com': 'Lowell Bezanis',
#  'per.sekse@enron.com': 'Stewart Seeligson',
#  'russell.dyk@enron.com': 'Russell Dyk',
#  'sachin.gandhi@enron.com': 'Sachin Gandhi',
#  'sandra.brawner@enron.com': 'Sandra F Brawner',
#  'matthew.arnold@enron.com': 'Matthew Arnold',
#  'sarah.wesner@enron.com': 'Sarah Wesner',
#  'catherine.pernot@enron.com': 'Catherine Pernot',
#  'lydia.cannon@enron.com': 'Lydia Cannon',
#  'teresa.smith@enron.com': 'Teresa Smith',
#  'diana.ovalle@enron.com': 'Diana Ovalle',
#  'mary.weatherstone@enron.com': 'Mary Weatherstone',
#  'dick.jenkins@enron.com': 'Dick Jenkins',
#  'amy.gambill@enron.com': 'Amy Gambill',
#  'eric.thode@enron.com': 'Eric Thode',
#  'frances.ortiz@enron.com': 'Frances Ortiz',
#  'david.dupre@enron.com': 'David P Dupre',
#  'anthony.gilmore@enron.com': 'Anthony Gilmore',
#  'andrew.lewis@enron.com': 'Andrew H Lewis',
#  'carey.metz@enron.com': 'Carey M Metz',
#  'dan.junek@enron.com': 'Dan Junek',
#  'danny.conner@enron.com': 'Danny conner',
#  'daren.farmer@enron.com': 'Daren J Farmer',
#  'edward.gottlob@enron.com': 'Edward D Gottlob',
#  'elsa.villarreal@enron.com': 'Elsa Villarreal',
#  'gary.lamphier@enron.com': 'Gary W Lamphier',
#  'greg.mcclendon@enron.com': 'Greg McClendon',
#  'jared.kaiser@enron.com': 'Jared Kaiser',
#  'jason.williams@enron.com': 'Jason Williams',
#  'john.taylor@enron.com': 'John Taylor',
#  'kelli.stevens@enron.com': 'Kelli Stevens',
#  'lauri.allen@enron.com': 'Lauri A Allen',
#  'liz.bellamy@enron.com': 'Liz Bellamy',
#  'patrice.mims@enron.com': 'Patrice L Mims',
#  'peter.keavey@enron.com': 'Peter F Keavey',
#  'robin.barbe@enron.com': 'Robin Barbe',
#  'stacey.neuweiler@enron.com': 'Stacey Neuweiler',
#  'susan.pereira@enron.com': 'Susan W Pereira',
#  'sylvia.pollan@enron.com': 'Sylvia S Pollan',
#  'tammi.depaolis@enron.com': 'Tammi DePaolis',
#  'airam.arteaga@enron.com': 'Airam Arteaga',
#  'kimberly.brown@enron.com': 'Kimberly Brown',
#  'laura.harder@enron.com': 'Laura Harder',
#  'margaret.allen@enron.com': 'Margaret Allen',
#  'alex.mcleish@enron.com': 'Alex McLeish',
#  'david.botchlett@enron.com': 'David J Botchlett',
#  'elizabeth.shim@enron.com': 'Elizabeth Shim',
#  'peter.berzins@enron.com': 'Peter Berzins',
#  'errol.mclaughlin@enron.com': 'Errol McLaughlin Jr.',
#  'stinson.gibner@enron.com': 'Stinson Gibner',
#  'heather.alon@enron.com': 'Heather Alon',
#  'colin.bailey@enron.com': 'Colin Bailey',
#  'sam.kemp@enron.com': 'Sam Kemp',
#  'tammy.shepperd@enron.com': 'Tammy R Shepperd',
#  'rajib.saha@enron.com': 'Rajib Saha',
#  'daniel.coleman@enron.com': 'Daniel Coleman',
#  'craig.brown@enron.com': 'Craig H Brown',
#  'carrie.robert@enron.com': 'Carrie A Robert',
#  'michael.brown@enron.com': 'Michael Brown',
#  'kevin.presto@enron.com': 'Kevin Presto',
#  'david.pruner@enron.com': 'David Pruner',
#  'kori.loibl@enron.com': 'Kori Loibl',
#  'allen.elliott@enron.com': 'Roy Elizondo',
#  'fangming.zhu@enron.com': 'Fangming Zhu',
#  'heidi.smith@enron.com': 'Heidi Smith',
#  'kristin.gandy@enron.com': 'Kristin Gandy',
#  'cliff.baxter@enron.com': 'Cliff Baxter',
#  'john.bone@enron.com': 'John Bone',
#  'ted.murphy@enron.com': 'Ted Murphy',
#  'david.redmond@enron.com': 'David Redmond',
#  'w.duran@enron.com': 'W David Duran',
#  'jennifer.milligan@enron.com': 'Jennifer Milligan',
#  'john.thomas@enron.com': 'John Buckner Thomas',
#  'rositza.smilenova@enron.com': 'Rositza Smilenova',
#  'lisa.honey@enron.com': 'Lisa Honey',
#  'michael.frost@enron.com': 'Michael Frost',
#  'roy.hartstein@enron.com': 'Roy Hartstein',
#  'shirley.wilson@enron.com': 'Shirley Jo Wilson',
#  'ali.khoja@enron.com': 'Heath Kendall',
#  'kathy.shaps@enron.com': 'Kathy Shaps',
#  'dave.forster@enron.com': 'dave forster',
#  'susan.wood@enron.com': 'Susan Wood',
#  'pamela.sonnier@enron.com': 'Pamela Sonnier',
#  'phil.clifford@enron.com': 'Phil Clifford',
#  'barbara.lewis@enron.com': 'Barbara Lewis',
#  'moe.barbarawi@enron.com': 'Moe Barbarawi',
#  'ravi.thuraisingham@enron.com': 'Jon Thomsen',
#  'sally.slaughter@enron.com': 'Sally Slaughter',
#  'debbie.flores@enron.com': 'Debbie Flores',
#  'gregory.carraway@enron.com': 'Gregory Carraway',
#  'douglas.friedman@enron.com': 'Douglas S Friedman',
#  'tanya.tamarchenko@enron.com': 'Tanya Tamarchenko',
#  'vince.kaminski@enron.com': 'Vince J Kaminski',
#  'bill.white@enron.com': 'Bill White',
#  'kevin.sweeney@enron.com': 'Shelly Stubbs',
#  'susan.lewis@enron.com': 'James C. Lewis',
#  'sandra.vu@enron.com': 'Sandra Vu',
#  'eva.pao@enron.com': 'Eva Pao',
#  'michael.corbally@enron.com': 'Michael Corbally',
#  'christie.patrick@enron.com': 'Christie Patrick',
#  'jim.lowe@enron.com': 'Jim Lowe',
#  'john.haggerty@enron.com': 'John Haggerty',
#  'john.ovanessian@enron.com': 'John Ovanessian',
#  'marla.thompson@enron.com': 'Marla Thompson',
#  'wendy.king@enron.com': 'Wendy King',
#  'jim.cole@enron.com': 'Jim Cole',
#  'robyn.zivic@enron.com': 'Robyn Zivic',
#  'angela.williams@enron.com': 'Angela Williams',
#  'bridget.fraser@enron.com': 'Bridget Fraser',
#  'john.disturnal@enron.com': 'John Disturnal',
#  'brett.wiggs@enron.com': 'Brett Wiggs',
#  'c.thompson@enron.com': 'C John Thompson',
#  'derek.davies@enron.com': 'Derek Davies',
#  'don.miller@enron.com': 'Jesus Melendrez',
#  'eric.ledain@enron.com': 'Eric LeDain',
#  'glen.devries@enron.com': 'Glen Devries',
#  'greg.wolfe@enron.com': 'Greg Wolfe',
#  'kyle.kitagawa@enron.com': 'Kyle Kitagawa',
#  'mark.davis@enron.com': 'Mark Dana Davis',
#  'mark.haedicke@enron.com': 'Mark Haedicke',
#  'michael.miller@enron.com': 'Karen S Owens@ees',
#  'orlando.gonzalez@enron.com': 'Orlando Gonzalez',
#  'paul.devries@enron.com': 'Waynette Detter',
#  'remi.collonges@enron.com': 'Remi Collonges',
#  'scott.josey@enron.com': 'Mary Joseph',
#  'bob.lee@enron.com': 'Bob Lee',
#  'zimin.lu@enron.com': 'Zimin Lu',
#  'mike.roberts@enron.com': 'Mike A Roberts',
#  ...}

# %%
inbox = Counter(lists['to']) + Counter(lists['cc'])

print("Recieved the most emails (including cc'd emails)")
for k,v in inbox.most_common(10) :
    print(people[k], ':', v)
    
print('------------------------------------------------------------')

nocc = Counter(lists['to'])
print("Recieved the most emails (not including cc'd emails)")
for  k,v in nocc.most_common(10) :
    print(people[k], ':', v)

print('------------------------------------------------------------')

print("Sent the most emails")
sent = Counter(lists['from'])
for k,v in sent.most_common(10) :
    print(people[k], ':', v)
    
onlycc = Counter(lists['cc'])
# Out:
# Recieved the most emails (including cc'd emails)
# Richard Shapiro : 17074
# Steven Kean : 15494
# Jeff Dasovich : 13415
# Tana Jones : 13169
# Mark Taylor : 11662
# James Steffes : 11660
# Sara Shackleton : 11485
# Vince J Kaminski : 9631
# Susan Mara : 9329
# Louise Kitchen : 9093
# ------------------------------------------------------------
# Recieved the most emails (not including cc'd emails)
# Richard Shapiro : 13069
# Steven Kean : 12321
# Tana Jones : 11246
# Jeff Dasovich : 11110
# Sara Shackleton : 9362
# James Steffes : 9067
# Mark Taylor : 8725
# Susan Mara : 8011
# Louise Kitchen : 7965
# John Lavorato : 7030
# ------------------------------------------------------------
# Sent the most emails
# Emmanuel Mangin : 11390
# Jeff Dasovich : 7836
# Tana Jones : 7696
# Vince J Kaminski : 7366
# Sara Shackleton : 7333
# Chris Germany : 6525
# Steven Kean : 5702
# Kate Symes : 5113
# Sally Beck : 3848
# Eric Bass : 3813

# %%
print(len(people.keys()))
# Out:
# 18277

# %%
to = dict(nocc)
fr = dict(sent)
cc = dict(onlycc)


rows = [['Name', 'E-mail', 'Number-From', 'Number-To', 'Number-CC']]

for k,v in people.items() :

    row = [v, k, fr.get(k, 0), to.get(k,0), cc.get(k,0)]
    
    rows.append(row)
    
rows[:10]
# Out:
# [['Name', 'E-mail', 'Number-From', 'Number-To', 'Number-CC'],
#  ['Phillip Allen', 'phillip.allen@enron.com', 1208, 2777, 475],
#  ['Keith Holst', 'keith.holst@enron.com', 37, 3058, 58],
#  ["Stephens 'vickersore@aol.com'",
#   'david.delainey@enron.com',
#   3007,
#   3068,
#   434],
#  ['Paula Harris', 'paula.harris@enron.com', 7, 208, 3],
#  ['Ina Rangel', 'ina.rangel@enron.com', 392, 1547, 349],
#  ['Jeffrey T Hodge', 'jeffrey.hodge@enron.com', 181, 3563, 641],
#  ['Cindy Cicchetti', 'cindy.cicchetti@enron.com', 0, 24, 19],
#  ['Christopher F Calger', 'christopher.calger@enron.com', 144, 2475, 420],
#  ['Kathy M Moore', 'kathy.moore@enron.com', 18, 66, 15]]

# %%
import csv
f = open('../../Output/Q1/messsagetotals.csv', 'w+', newline='')
try:
    writer = csv.writer(f)
    writer.writerows(rows)
finally:
    f.close()
